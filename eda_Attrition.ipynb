# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('attrition.csv')

# %%
df.sample(5)
# Out:
#       Age  Attrition BusinessTravel              Department EducationField  \
# 789    44          1  Travel_Rarely         Human Resources        Medical
# 1008   54          0  Travel_Rarely  Research & Development        Medical
# 50     48          1  Travel_Rarely  Research & Development  Life Sciences
# 1357   42          0  Travel_Rarely  Research & Development        Medical
# 996    27          0  Travel_Rarely                   Sales      Marketing
#
#       EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 789                         2    Male               2         3
# 1008                        4  Female               3         4
# 50                          1    Male               2         3
# 1357                        3    Male               3         3
# 996                         4  Female               2         2
#
#       JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# 789                 1       Married          10482       No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   int64
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   EducationField           1470 non-null   object
#  5   EnvironmentSatisfaction  1470 non-null   int64
#  6   Gender                   1470 non-null   object
#  7   JobInvolvement           1470 non-null   int64
#  8   JobLevel                 1470 non-null   int64
#  9   JobSatisfaction          1470 non-null   int64
#  10  MaritalStatus            1470 non-null   object
#  11  MonthlyIncome            1470 non-null   int64
#  12  OverTime                 1470 non-null   object
#  13  TotalWorkingYears        1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    Attrition  EnvironmentSatisfaction  JobInvolvement  \
# count  1470.000000  1470.000000              1470.000000     1470.000000
# mean     36.923810     0.161224                 2.721769        2.729932
# std       9.135373     0.367863                 1.093082        0.711561
# min      18.000000     0.000000                 1.000000        1.000000
# 25%      30.000000     0.000000                 2.000000        2.000000
# 50%      36.000000     0.000000                 3.000000        3.000000
# 75%      43.000000     0.000000                 4.000000        3.000000
# max      60.000000     1.000000                 4.000000        4.000000
#
#           JobLevel  JobSatisfaction  MonthlyIncome  TotalWorkingYears  \
# count  1470.000000      1470.000000    1470.000000        1470.000000
# mean      2.063946         2.728571    6502.931293          11.279592
# std       1.106940         1.102846    4707.956783           7.780782
# ...

# %% [markdown]
# ## List of Questions
#
#
# #### Monthly income
# - Is lower income a factor for attrition?
# - Is there a gender bias in income?
# - Those who left, are they towards lower job level?
# - Are Married people leaving because of lower salary?
# - Is there a difference in salary level across Education field?
# - Attrition is high at which job level based on income?
# - Is there a difference in salary levels across Departments?
#
# #### Gender and Age
# - What is the gender ratio?
# - How is age varying in the company?
# - How Age varies over gender?
# - Are those who leaving young?
#
# #### Satisfaction Level
# - Is job satisfaction a factor for Attrition?
# - Is there a difference environment satisfaction between Genders?
# - Is there a difference in job satisfaction between Genders?
# - How is the WorkLifeBalance in company?
# - How does job satisfaction vary across Department?
# - How is DistanceFromHome affecting attrition?
#
#
# #### Department
# - Which department saw highest attrition?
# - Is any department skewed towards any gender?
# - How is Job Involvement across the Departments?
# - Is any department providing more overtime?
# - How is Work Life Balance across Departments?
#
# #### Working Years
# - Is there a pattern in those who leave in terms of the number of year?
# - Does YearsSinceLastPromotion affect attrition?
# - Does Years in current role affect attrition?
#
# #### Marital Status?
# - Business travel and Marital Status?
# - Overtime and Marital Status affecting attrition?
# - WorklifeBalance for Married people?

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Monthly income
# - Is lower income a factor for attrition?
# - Is there a gender bias in income?
# - Those who left, are they towards lower job satisfaction level?
# - Are Married people leaving because of lower salary?
# - Is there a difference in salary level across Education field?
# - Attrition is high at which job level based on income?
# - Is there a difference in salary levels across Departments?

# %%
sns.distplot(df['MonthlyIncome'])

# %%
sns.boxplot(data=df, x='Attrition', y='MonthlyIncome')

# %%
sns.swarmplot(data=df, x= 'Attrition', y = 'MonthlyIncome')

# %%
sns.boxplot(data=df, x='Gender', y='MonthlyIncome', hue='Attrition')

# %%
sns.boxplot(data=df, x='Attrition', y='MonthlyIncome', hue='Gender')

# %%
sns.boxplot(data=df, x='Attrition', y='MonthlyIncome', hue='JobSatisfaction')

# %%
sns.boxplot(data=df, x='MaritalStatus', y='MonthlyIncome', hue='Attrition')

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df, x='EducationField', y='MonthlyIncome', hue='Attrition')

# %%
sns.boxplot(data=df, x='JobLevel', y='MonthlyIncome', hue='Attrition')

# %%
sns.boxplot(data=df, x='Department', y='MonthlyIncome', hue='Attrition')

# %% [markdown]
# * A Lower Monthly Income is observed for those who left the company
#
# * Divorced individuals who left the company seem to have been getting the lowest salary, while singles getting a low salary can be attributed to the young early career persons where attrition is usally common
#
# * Across education field, those who left from HR got less than 25% percentile salary of others still working in HR. A similar but not drastically varying difference id observed in Technical Degree, Medical degree and Other category as well.
#
# * The above is observed in HR dpeartment and R&D department and well
#
# * At job level 4 Attrition could be attributed to poor Monthly Income. Month Income isnt showing much variation at other job levels
#
# **Attrition at lower monthly income is observed across different categoies**

# %% [markdown]
# ---

# %% [markdown]
# ## Gender and Age
# - What is the gender ratio?
# - How is age varying in the company?
# - How Age varies over gender?
# - Are those who leaving young?

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Male      0.6
# Female    0.4
# Name: Gender, dtype: float64

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=df, x='Age')

# %%
age_filter = df['Attrition'] == 1
df_age_1 = df[age_filter]
plt.hist(df_age_1['Age'],cumulative=True, density=True, bins=30)
#sns.distplot(df_age_1['Age'], hist_kws={'cumulative': True}, kde_kws={'cumulative': True})
# Out:
# (array([0.04219409, 0.06751055, 0.092827  , 0.13080169, 0.16033755,
#         0.18565401, 0.24894515, 0.30801688, 0.38396624, 0.4978903 ,
#         0.5443038 , 0.59493671, 0.67510549, 0.70042194, 0.7257384 ,
#         0.75949367, 0.78059072, 0.80590717, 0.82278481, 0.84810127,
#         0.85654008, 0.88607595, 0.89451477, 0.90295359, 0.93248945,
#         0.94514768, 0.9535865 , 0.96624473, 0.97890295, 1.        ]),
#  array([18.        , 19.33333333, 20.66666667, 22.        , 23.33333333,
#         24.66666667, 26.        , 27.33333333, 28.66666667, 30.        ,
#         31.33333333, 32.66666667, 34.        , 35.33333333, 36.66666667,
#         38.        , 39.33333333, 40.66666667, 42.        , 43.33333333,
#         44.66666667, 46.        , 47.33333333, 48.66666667, 50.        ,
#         51.33333333, 52.66666667, 54.        , 55.33333333, 56.66666667,
#         58.        ]),
#  <a list of 30 Patch objects>)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Age', y='MonthlyIncome', hue='Attrition')

# %%
sns.boxplot(data=df, x='Gender', y='Age', hue='Attrition')

# %%
plt.figure(figsize=(20,8))
sns.relplot(
    data=df, x="Age", y="MonthlyIncome",
     hue="Attrition", style="Attrition",
    kind="line"
)

# %% [markdown]
# * In the company 60% of the workers are males and 40% females
# * Most of the employees fall in the 26 - 45 age range
# * Attrition seems to be high in the under 30 age bracket
# * Younger females seem to be leaving the company more than younger males. This could be attributed to situations like marriage, family concerns or relocations

# %% [markdown]
# ---

# %% [markdown]
# ## Satisfaction Level
# - Is job satisfaction a factor for Attrition?
# - Is there a difference environment satisfaction between Genders?
# - Is there a difference in job satisfaction between Genders?
# - How is the WorkLifeBalance in company?
# - How does job satisfaction vary across Department?
# - How is DistanceFromHome affecting attrition?

# %%
sns.countplot(df['JobSatisfaction'])

# %%
pd.crosstab(df['JobSatisfaction'], df['Attrition'], normalize=True)
# Out:
# Attrition               0         1
# JobSatisfaction
# 1                0.151701  0.044898
# 2                0.159184  0.031293
# 3                0.251020  0.049660
# 4                0.276871  0.035374

# %%
sns.boxplot(y=df['JobSatisfaction'], x=df['Attrition'])

# %%
sns.boxplot(data=df, x='JobSatisfaction', y='Gender', hue='Attrition')

# %%
sns.countplot(df[df['Attrition']==1]['JobSatisfaction'],hue=df['Gender'])

# %%
sns.boxplot(data=df, x='EnvironmentSatisfaction', y='Gender', hue='Attrition')

# %%
pd.crosstab(df['WorkLifeBalance'], df['JobSatisfaction'], normalize='index')
# Out:
# JobSatisfaction         1         2         3         4
# WorkLifeBalance
# 1                0.212500  0.225000  0.262500  0.300000
# 2                0.177326  0.168605  0.293605  0.360465
# 3                0.203807  0.195969  0.305711  0.294513
# 4                0.189542  0.189542  0.307190  0.313725

# %%
sns.countplot(df['WorkLifeBalance'])

# %%
sns.countplot(data=df, x='Department',hue='JobSatisfaction')

# %%
sns.countplot(df['WorkLifeBalance'], hue=df['Gender'])

# %%
sns.relplot(data=df, x='Age', y='DistanceFromHome',
          hue='Attrition', style='Attrition', kind='line')

# %%
df[(df['DistanceFromHome']>=9)].shape
# Out:
# (615, 20)

# %%
df[(df['DistanceFromHome']<9)].shape
# Out:
# (855, 20)

# %%
df[(df['DistanceFromHome']>=9) & (df['Attrition']==1)].shape
# Out:
# (122, 20)

# %%
df[(df['DistanceFromHome']>=9) & (df['Attrition']==0)].shape
# Out:
# (493, 20)

# %%
df[(df['DistanceFromHome']<9) & (df['Attrition']==0)].shape
# Out:
# (740, 20)

# %%
df[(df['DistanceFromHome']<9) & (df['Attrition']==1)].shape
# Out:
# (115, 20)

# %%
122/237
# Out:
# 0.5147679324894515

# %%
df['DistanceFromHome'].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %% [markdown]
# * Higher job satisfaction levels are observed in the company
# * Among those who left a slightly lower job satisfaction is observed especially in Males
# * A lower environment satisfaction levels is probable among the Females who left but cannot be generalised for women still in the company reported higher Environment Satisfaction
# * WorkLifeBalance does not seem to be a major concern
# * 51% of those who left the company stay more than 9 miles away

# %% [markdown]
# ---

# %% [markdown]
# # Department
# - Which department saw highest attrition?
# - Is any department skewed towards any gender?
# - How is Job Involvement across the Departments?
# - Is any department providing more overtime?
# - How is Work Life Balance across Departments?

# %%
sns.countplot(df['Department'], hue=df['Attrition'])

# %%
pd.crosstab(df['Department'], df['Attrition'], normalize='columns')
# Out:
# Attrition                      0         1
# Department
# Human Resources         0.041363  0.050633
# Research & Development  0.671533  0.561181
# Sales                   0.287105  0.388186

# %%
sns.countplot(df['Department'], hue= df['Gender'])

# %%
df_left = df[df['Attrition']==1]
sns.swarmplot( data= df_left, y= 'Age', x= 'Department', hue='JobInvolvement')

# %%
df_left = df[df['Attrition']==1]
sns.swarmplot( data= df, y= 'Age', x= 'Department', hue='OverTime')

# %%
sns.scatterplot( data= df, x= 'Age', y= 'MonthlyIncome', hue='OverTime')

# %%
plt.figure(figsize=(20,8))
sns.relplot(
    data=df, x="TotalWorkingYears", y="MonthlyIncome",
     hue="OverTime", col="Attrition",
    kind="line"
)

# %%
sns.countplot(df['Department'], hue=df['WorkLifeBalance'])

# %% [markdown]
# * 56% of attrition is observed in R&D department and and 38% in Sales department
# * High job involvement is observed in the company
# * OverTime options seem to be few in the company
# * Those who did overtime seem to be making appriximately the same as those who arent doing Overtime

# %% [markdown]
# ---

# %% [markdown]
# # Working Years
# - Is there a pattern in those who leave in terms of the number of year?
# - Does YearsSinceLastPromotion affect attrition?
# - Does Years in current role affect attrition?

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='YearsInCurrentRole', hue='Attrition')

# %% [markdown]
# * Immeditely after appointment to current role i.e. promotion or hiring people are leaving within few months
# * 2 year mark is also a crucial point for arttrition

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='TotalWorkingYears', hue='Attrition')

# %% [markdown]
# * high attrition is observed in people with 1 and 0 years of experience
# * can be further examined by checking the TotalWorkingYears parameter

# %%
new_df =df[df['TotalWorkingYears']<=1] #can be checked for 2 years also
new_df['YearsInCurrentRole'].value_counts()
# Out:
# 0    82
# 1    10
# Name: YearsInCurrentRole, dtype: int64

# %%
new_df['Attrition'].value_counts()
# Out:
# 0    47
# 1    45
# Name: Attrition, dtype: int64

# %% [markdown]
# * High Attrition in joinees under 1 year experience

# %%
sns.countplot(new_df['Age'], hue=new_df['Attrition'])

# %%
sns.countplot(df['YearsWithCurrManager'], hue=df['Attrition'])

# %%
# 0,2,7 Years with current manager has 70% of the attrition. This might be related to TotalWorking Years variable
df[((df['YearsWithCurrManager'] == 0) |(df['YearsWithCurrManager'] == 2) | (df['YearsWithCurrManager'] == 7))]['Attrition'].value_counts()
# Out:
# 0    657
# 1    166
# Name: Attrition, dtype: int64

# %%
sns.countplot(df['YearsAtCompany'], hue=df['Attrition'])

# %% [markdown]
# * High attrition with persons having less than 1 TotalWorkingYears. Also, immeditely after appointment to current role i.e. through promotion or hiring people are leaving within few months.
# * upto 2 year mark is also a crucial point for arttrition

# %% [markdown]
# ---

# %% [markdown]
# - Business travel
# - Overtime and Marital Status affecting attrition?
# - WorklifeBalance for Married people?

# %%
sns.countplot(df['BusinessTravel'], hue=df['Attrition'])

# %%
pd.crosstab(df['BusinessTravel'], df['Attrition'], normalize='index')
# Out:
# Attrition                 0         1
# BusinessTravel
# Non-Travel         0.920000  0.080000
# Travel_Frequently  0.750903  0.249097
# Travel_Rarely      0.850431  0.149569

# %%
sns.countplot(df_left['MaritalStatus'], hue=df_left['OverTime'])

# %%
sns.countplot(df_left['WorkLifeBalance'], hue=df_left['MaritalStatus'])

# %% [markdown]
# * 25% of those who travel frequently have left the company while the figures are lower at 8% non travel and 15% travel rarely
# * More singles have left the company which may point to the young leaving
# * Fewer ratings for highest worklifebalance category. Martital status has no effect

# %% [markdown]
# ---

# %% [markdown]
# # Attrition

# %%
df['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
sns.countplot(df['BusinessTravel'])

# %% [markdown]
# **A cluster in attrition is observed in the lower range of age between 18 and 30 years of age**

# %% [markdown]
# ---

# %% [markdown]
# # SUMMARY
#
# * **Monthly Income** affects attrition. The lower the monthly income, higher the chance of leaving, as observed across different categories
#
# * With 40% of the workforce being female, the company may project an inclusive Evironment and conducting female only recruitment drives to increase the female to male ratio, also ensuring enough female bosses exist up the hierarchy. This could be a suggestion in light of the slightly lower environment satisfaction among females who left the company
#
# * Attrition is observed in the lower **age** group
#
# * **Overtime** benefits don't seem to be much beneficial or adding to the income of people
#
# * **TotalWorkingYears:** * High attrition with persons having less than 1 TotalWorkingYears. Also, immeditely after appointment to current role i.e. through promotion or hiring people are leaving within few months. A similar conclusion is observed in the other parameters ie.YearsInCurrentRole YearsAtCompany and YearsWithCurrManager
